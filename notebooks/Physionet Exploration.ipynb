# %%
import sys

sys.path.append(r"../src")


import os
import numpy as np
import matplotlib.pyplot as plt

os.chdir(r"../")
os.getcwd()
# Out:
# 'C:\\Developments\\New folder'

# %%
data = np.load(r"C:\Developments\New folder\VAEImputer\data\PHYSIONET\physionet.npz")

# %%
data.files
# Out:
# ['x_train_full',
#  'x_train_miss',
#  'm_train_miss',
#  'm_train_artificial',
#  'y_train',
#  'x_val_full',
#  'x_val_miss',
#  'm_val_miss',
#  'm_val_artificial',
#  'y_val',
#  'x_test_full',
#  'x_test_miss',
#  'm_test_miss',
#  'm_test_artificial',
#  'y_test']

# %%
x_train_full = data['x_train_full']
x_train_full.shape
# Out:
# (3997, 48, 35)

# %%
x_val_full = data['x_val_full']
x_val_full.shape
# Out:
# (3993, 48, 35)

# %%
x_test_full = data['x_test_full']
x_test_full.shape
# Out:
# (3997, 48, 35)

# %%
x_test_full = data['y_test']
x_test_full.shape
# Out:
# (3997,)

# %%
set(x_test_full)
# Out:
# {0, 1}
